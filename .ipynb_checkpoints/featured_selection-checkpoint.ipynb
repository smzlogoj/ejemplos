# %%
load('.RData')

# %%
library(FSelector)
library(RColorBrewer)
library(caret)
# Out:
# Loading required package: ggplot2
#
# Loading required package: lattice

# %%
## Eliminar Mouse 3484
df <- df[df$Mouse != 3484, ]

# %%
df.c_s <- df[df$Genotype == 'Control' & df$Treatment == 'Saline', c('Behavior', proteinas)]

# %% [markdown]
# ## 1. Importance Gain

# %%
head(df.c_s)
# Out:
#        Behavior DYRK1A_N  ITSN1_N   BDNF_N    NR1_N    NR2A_N   pAKT_N
# 3477_1 CS       0.5916184 0.8149799 0.4149799 2.706108 5.256264 0.2609897
# 3477_2 CS       0.5898067 0.8404449 0.4243253 2.803702 5.534373 0.2694201
# 3477_3 CS       0.5989016 0.8860412 0.4447597 2.918261 5.717712 0.2904348
# 3477_4 CS       0.5448436 0.7269988 0.3908459 2.521089 4.967323 0.2755504
# 3477_5 CS       0.5127852 0.7306502 0.3891756 2.514047 5.070519 0.2718725
# 3477_6 CS       0.5421644 0.7804849 0.4145476 2.672383 5.691898 0.2835009
#        pBRAF_N   pCAMKII_N pCREB_N   ⋯ P3525_N   pCASP9_N PSD95_N  SNCA_N
# 3477_1 0.1872492 4.163798  0.2658939 ⋯ 0.3161974 1.598026 1.903538 0.1279904
# 3477_2 0.1928337 4.284555  0.2759847 ⋯ 0.3231917 1.597113 1.987210 0.1458747
# 3477_3 0.1971625 4.497666  0.2822883 ⋯ 0.3040895 1.521701 1.851042 0.1418094
# 3477_4 0.1909618 4.576825  0.2402086 ⋯ 0.3019977 1.516816 1.951827 0.1225187
# 3477_5 0.1886252 4.548217  0.2383901 ⋯ 0.3260649 1.527257 1.942254 0.1370436
# 3477_6 0.1986990 4.806978  0.2560615 ⋯ 0.3139563 1.436650 1.886165 0.1348908
#        Ubiquitin_N pGSK3B_Tyr216_N SHH_N     pS6_N     SYP_N     CaNA_N
# 3477_1 1.1052226   0.7147052       0.2162696 0.1211552 0.4000481 1.399615
# 3477_2 1.0931156   0.7302941       0.2206288 0.1253331 0.3988663 1.410978
# 3477_3 0.9987003   0.6903867       0.2306085 0.1186000 0.3787309 1.332266
# 3477_4 1.0786446   0.7160197       0.2107093 0.1177140 0.3855102 1.394424
# 3477_5 1.0477307   0.7195740       0.2228068 0.1242394 0.3857759 1.366823
# 3477_6 1.0755461   0.7015170       0.2353155 0.1170510 0.3673544 1.320328

# %%
options(repr.plot.width = 12, repr.plot.height = 7)

# %%
importance <- information.gain(Behavior~., df.c_s[, c('Behavior', proteinas)])
importance$attr_importance <- round(importance$attr_importance, 2)
importance$feature <- rownames(importance)
orden <- importance[order(importance$attr_importance, decreasing = TRUE), 'feature']

ggplot(data = importance, aes(x = factor(feature, levels = orden), 
                              y = attr_importance, fill = feature)) +
        geom_bar(stat = 'identity') +
        theme_bw() +
        theme(legend.position = 'none', axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %% [markdown]
# ## 2. Remove Redundant Features
#
# Data can contain attributes that are highly correlated with each other. Many methods perform better if highly correlated attributes are removed.
#
# Generally, you want to remove attributes with an absolute correlation of 0.75 or higher.

# %%
correlationMatrix <- cor(df.c_s[, 2:70], use = 'pairwise.complete.obs')
highlyCorrelated <- findCorrelation(correlationMatrix, cutoff=0.75)
highCorrelatedColumns <- colnames(correlationMatrix[, highlyCorrelated])
highCorrelatedColumns
# Out:
#  [1] "BDNF_N"       "MEK_N"        "ITSN1_N"      "TRKA_N"       "NR1_N"
#  [6] "pMTOR_N"      "AMPKA_N"      "ERK_N"        "pNUMB_N"      "pNR1_N"
# [11] "TIAM1_N"      "BRAF_N"       "DYRK1A_N"     "RAPTOR_N"     "NR2A_N"
# [16] "PKCA_N"       "NR2B_N"       "pJNK_N"       "CAMKII_N"     "pMEK_N"
# [21] "JNK_N"        "MTOR_N"       "NUMB_N"       "nNOS_N"       "ARC_N"
# [26] "pBRAF_N"      "pAKT_N"       "RSK_N"        "pGSK3B_N"     "GluR4_N"
# [31] "AcetylH3K9_N"

# %% [markdown]
# ## 3. Rank Features By Importance
# The importance of features can be estimated from data by building a model. Some methods like decision trees have a built in mechanism to report on variable importance. For other algorithms, the importance can be estimated using a ROC curve analysis conducted for each attribute.

# %%
fit_control <- trainControl(## 10-fold CV
                           method = "repeatedcv",
                           number = 10,
                           ## repeated ten times
                           repeats = 10,
                           classProbs=TRUE)

# %%
set.seed(57)
index <- createDataPartition(df.c_s$Behavior, p = 0.75, list = FALSE)
train_data <- df.c_s[index,]
test_data <- df.c_s[-index,]
sprintf("The trainining set contains %d rows", nrow(train_data))
sprintf("The test set contains %d rows", nrow(test_data))

table(train_data$Behavior)
# Out:
# [1] "The trainining set contains 189 rows"
# [1] "The test set contains 62 rows"
#  CS  SC
#  87 102

# %%
## Centrado, escalado, e imputacion de NA por Knn
preProcValues <- preProcess(train_data, method = c('center', 'scale', 'knnImpute'))
trainTransformed <- predict(preProcValues, train_data)
testTransformed <- predict(preProcValues, test_data)

# %%
#### OJO ### Varios minutos de computacion
model <- train(Behavior~., 
               data = trainTransformed[, c('Behavior', proteinas)], 
               method='rf', metric = 'Accuracy', trControl=fit_control)

# %%
model
# Out:
# Random Forest
#
# 189 samples
#  69 predictor
#   2 classes: 'CS', 'SC'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold, repeated 10 times)
# Summary of sample sizes: 170, 170, 169, 171, 170, 170, ...
# Resampling results across tuning parameters:
#
#   mtry  Accuracy   Kappa
#    2    1.0000000  1.0000000
#   35    0.9952018  0.9902546
#   69    0.9946754  0.9891932
#
# Accuracy was used to select the optimal model using the largest value.
# The final value used for the model was mtry = 2.

# %%
importance <- varImp(model, scale=FALSE)
print(importance)
plot(importance)
# Out:
# rf variable importance
#
#   only 20 most important variables shown (out of 69)
#
#             Overall
# SOD1_N        5.716
# pS6_N         4.893
# ARC_N         4.387
# pERK_N        4.111
# pPKCAB_N      4.101
# IL1B_N        3.492
# DYRK1A_N      3.465
# CaNA_N        3.378
# pNUMB_N       3.193
# Ubiquitin_N   2.709
# SNCA_N        2.583
# nNOS_N        2.537
# ITSN1_N       2.515
# PSD95_N       2.398
# pGSK3B_N      2.334
# AKT_N         2.058
# GSK3B_N       2.039
# PKCA_N        2.012
# P38_N         1.899
# BRAF_N        1.594
# plot without title

# %% [markdown]
# ## 4. Recursive Feature Elimination

# %%
rfe_control <- rfeControl(functions=rfFuncs, method="cv", number=10)

# %%
#Mucho tiempo de computación
results <- rfe(trainTransformed[, c(proteinas)], trainTransformed$Behavior, sizes=c(1:69), rfeControl=rfe_control)

# %%
results
# Out:
# Recursive feature selection
#
# Outer resampling method: Cross-Validated (10 fold)
#
# Resampling performance over subset size:
#
#  Variables Accuracy  Kappa AccuracySD KappaSD Selected
#          1   0.9892 0.9781    0.02282 0.04620
#          2   1.0000 1.0000    0.00000 0.00000        *
#          3   1.0000 1.0000    0.00000 0.00000
#          4   0.9944 0.9886    0.01757 0.03603
#          5   1.0000 1.0000    0.00000 0.00000
#          6   1.0000 1.0000    0.00000 0.00000
#          7   1.0000 1.0000    0.00000 0.00000
#          8   1.0000 1.0000    0.00000 0.00000
#          9   1.0000 1.0000    0.00000 0.00000
#         10   1.0000 1.0000    0.00000 0.00000
#         11   1.0000 1.0000    0.00000 0.00000
#         12   1.0000 1.0000    0.00000 0.00000
#         13   1.0000 1.0000    0.00000 0.00000
#         14   1.0000 1.0000    0.00000 0.00000
#         15   1.0000 1.0000    0.00000 0.00000
#         16   1.0000 1.0000    0.00000 0.00000
#         17   1.0000 1.0000    0.00000 0.00000
#         18   1.0000 1.0000    0.00000 0.00000
#         19   1.0000 1.0000    0.00000 0.00000
#         20   1.0000 1.0000    0.00000 0.00000
#         21   1.0000 1.0000    0.00000 0.00000
#         22   1.0000 1.0000    0.00000 0.00000
#         23   1.0000 1.0000    0.00000 0.00000
#         24   1.0000 1.0000    0.00000 0.00000
#         25   1.0000 1.0000    0.00000 0.00000
#         26   1.0000 1.0000    0.00000 0.00000
#         27   1.0000 1.0000    0.00000 0.00000
#         28   1.0000 1.0000    0.00000 0.00000
#         29   1.0000 1.0000    0.00000 0.00000
#         30   1.0000 1.0000    0.00000 0.00000
#         31   1.0000 1.0000    0.00000 0.00000
#         32   1.0000 1.0000    0.00000 0.00000
#         33   1.0000 1.0000    0.00000 0.00000
#         34   1.0000 1.0000    0.00000 0.00000
#         35   1.0000 1.0000    0.00000 0.00000
#         36   1.0000 1.0000    0.00000 0.00000
#         37   1.0000 1.0000    0.00000 0.00000
#         38   1.0000 1.0000    0.00000 0.00000
#         39   1.0000 1.0000    0.00000 0.00000
#         40   1.0000 1.0000    0.00000 0.00000
#         41   1.0000 1.0000    0.00000 0.00000
#         42   1.0000 1.0000    0.00000 0.00000
#         43   1.0000 1.0000    0.00000 0.00000
#         44   1.0000 1.0000    0.00000 0.00000
#         45   1.0000 1.0000    0.00000 0.00000
#         46   1.0000 1.0000    0.00000 0.00000
#         47   1.0000 1.0000    0.00000 0.00000
#         48   1.0000 1.0000    0.00000 0.00000
#         49   1.0000 1.0000    0.00000 0.00000
#         50   1.0000 1.0000    0.00000 0.00000
#         51   1.0000 1.0000    0.00000 0.00000
#         52   1.0000 1.0000    0.00000 0.00000
#         53   1.0000 1.0000    0.00000 0.00000
#         54   1.0000 1.0000    0.00000 0.00000
#         55   1.0000 1.0000    0.00000 0.00000
#         56   1.0000 1.0000    0.00000 0.00000
#         57   1.0000 1.0000    0.00000 0.00000
#         58   1.0000 1.0000    0.00000 0.00000
#         59   1.0000 1.0000    0.00000 0.00000
#         60   1.0000 1.0000    0.00000 0.00000
#         61   1.0000 1.0000    0.00000 0.00000
#         62   1.0000 1.0000    0.00000 0.00000
#         63   1.0000 1.0000    0.00000 0.00000
#         64   1.0000 1.0000    0.00000 0.00000
#         65   1.0000 1.0000    0.00000 0.00000
#         66   1.0000 1.0000    0.00000 0.00000
#         67   1.0000 1.0000    0.00000 0.00000
#         68   1.0000 1.0000    0.00000 0.00000
#         69   1.0000 1.0000    0.00000 0.00000
#
# The top 2 variables (out of 2):
#    SOD1_N, pERK_N

# %%
ggplot(df.c_s, aes(x = SOD1_N, y = pERK_N)) +
    geom_point(aes(color = Behavior)) +
    theme_bw()
# Out:
# plot without title

# %% [markdown]
# ## 5. Boruta

# %%
### Ver PDF

# Data Science
# and Predictive
# Analytics

# %%
library(Boruta)
set.seed(1234)
vs <- Boruta(Behavior~., data = df.c_s)

# %%
print(vs)
plot(vs, xlab="", xaxt="n")
# Out:
# Boruta performed 99 iterations in 4.407648 secs.
#  58 attributes confirmed important: AcetylH3K9_N, ADARB1_N, AKT_N,
# AMPKA_N, APP_N and 53 more;
#  2 attributes confirmed unimportant: NR2A_N, TRKA_N;
#  9 tentative attributes left: CREB_N, GluR4_N, JNK_N, MEK_N, NR1_N and
# 4 more;
# plot without title

# %%
getSelectedAttributes(vs, withTentative = FALSE)
# Out:
#  [1] "DYRK1A_N"        "ITSN1_N"         "BDNF_N"          "pAKT_N"
#  [5] "pBRAF_N"         "pCAMKII_N"       "pELK_N"          "pERK_N"
#  [9] "pJNK_N"          "PKCA_N"          "pMEK_N"          "pNR2A_N"
# [13] "pPKCAB_N"        "pRSK_N"          "AKT_N"           "BRAF_N"
# [17] "CAMKII_N"        "ERK_N"           "GSK3B_N"         "RSK_N"
# [21] "APP_N"           "SOD1_N"          "MTOR_N"          "P38_N"
# [25] "pMTOR_N"         "DSCR1_N"         "AMPKA_N"         "NR2B_N"
# [29] "pNUMB_N"         "RAPTOR_N"        "TIAM1_N"         "pP70S6_N"
# [33] "NUMB_N"          "P70S6_N"         "pGSK3B_N"        "pPKCG_N"
# [37] "CDK5_N"          "S6_N"            "ADARB1_N"        "AcetylH3K9_N"
# [41] "RRP1_N"          "BAX_N"           "ARC_N"           "ERBB4_N"
# [45] "nNOS_N"          "Tau_N"           "GFAP_N"          "GluR3_N"
# [49] "IL1B_N"          "P3525_N"         "pCASP9_N"        "PSD95_N"
# [53] "SNCA_N"          "Ubiquitin_N"     "pGSK3B_Tyr216_N" "SHH_N"
# [57] "pS6_N"           "CaNA_N"

# %%
plotImpHistory(vs)
# Out:
# plot without title

# %%
selected_variables <- orden[1:5]

# %%
save.image()
